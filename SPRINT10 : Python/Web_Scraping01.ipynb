# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from io import StringIO

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

# %%
url = 'https://www.set.or.th/en/market/product/stock/quote/TISCO/financial-statement/company-highlights'

# %%
driver.get(url)

# %%
# driver.page_source

# %%
df = pd.read_html(StringIO(driver.page_source))

# %%
df[0]
# Out:
#                            Period as of  Y/E 2019 31 Dec 2019  \
# 0                        Financial Data                   NaN
# 1                                Assets             298304.10
# 2                           Liabilities             259107.98
# 3                                Equity              39192.98
# 4                       Paid-up Capital               8006.56
# 5                               Revenue              24855.50
# 6   Profit (Loss) from Other Activities                 -5.30
# 7                            Net Profit               7270.23
# 8                            EPS (Baht)                  9.08
# 9                       Financial Ratio                   NaN
# 10                              ROA (%)                  4.71
# 11                              ROE (%)                 18.91
# 12                Net Profit Margin (%)                 29.26
#
#     Y/E 2020 31 Dec 2020  Y/E 2021 31 Dec 2021  Y/E 2022 31 Dec 2022  \
# 0                    NaN                   NaN                   NaN
# 1              275443.21             243621.93             265414.44
# 2              235981.13             202421.55             222623.81
# 3               39458.94              41197.09              42787.39
# 4                8006.56               8006.56               8006.56
# 5               22865.95              21265.45              20784.02
# 6                  10.66                417.33                144.70
# 7                6063.48               6784.59               7224.08
# 8                   7.57                  8.47                  9.02
# 9                    NaN                   NaN                   NaN
# 10                  3.91                  4.17                  4.39
# 11                 15.42                 16.82                 17.20
# 12                 26.52                 31.91                 34.76
#
#     Y/E 2023 31 Dec 2023
# 0                    NaN
# 1              290724.25
# 2              248276.27
# 3               42444.87
# 4                8006.56
# 5               23692.47
# 6                   5.09
# 7                7301.11
# 8                   9.12
# 9                    NaN
# 10                  4.78
# 11                 17.13
# 12                 30.82

# %%
df[1]
# Out:
#               Statistics as of  30 Dec 2020  30 Dec 2021  30 Dec 2022  \
# 0            Last Price (Baht)        88.50        96.00        99.25
# 1         Market Cap. (M.Baht)     70857.14     76861.98     79464.08
# 2      F/S Period (As of date)  30 Sep 2020  30 Sep 2021  30 Sep 2022
# 3                          P/E        11.26        11.60        11.02
# 4                         P/BV         1.87         1.95         1.94
# 5  Book Value per share (Baht)        47.26        49.22        51.24
# 6           Dividend Yield (%)         8.76         6.56         7.20
#
#    28 Dec 2023  05 Apr 2024
# 0        99.75        99.00
# 1     79864.40     79263.92
# 2  30 Sep 2023  31 Dec 2023
# 3        10.90        10.86
# 4         1.97         1.87
# 5        50.55        53.01
# 6         7.77         7.83
