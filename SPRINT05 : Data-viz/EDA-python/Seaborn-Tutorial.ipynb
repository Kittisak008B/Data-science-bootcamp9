# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x= 'tip' , y= 'total_bill' ,data=tips , hue='day', size = 'size' , palette = 'viridis')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(tips['tip'] , kde = True , bins = 25)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.barplot(x = 'sex' , y = 'tip' , data =tips )
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='day', y='total_bill' , data = tips , hue ='sex' , palette ='flare')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='tip', data=tips , hue='sex' , dodge =True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='tip', y= 'total_bill' , data = tips , kind = 'reg' )

# %%
sns.jointplot(x='tip', y= 'total_bill' , data = tips , kind = 'kde' ,shade =True )

# %%
sns.jointplot(x='tip', y= 'total_bill' , data = tips , kind = 'hex' , cmap = 'rocket_r' )

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.iloc[:, [0,1,3,4,5,6,10,14]]
# Out:
#      survived  pclass   age  sibsp  parch     fare  adult_male  alone
# 0           0       3  22.0      1      0   7.2500        True  False
# 1           1       1  38.0      1      0  71.2833       False  False
# 2           1       3  26.0      0      0   7.9250       False   True
# 3           1       1  35.0      1      0  53.1000       False  False
# 4           0       3  35.0      0      0   8.0500        True   True
# ..        ...     ...   ...    ...    ...      ...         ...    ...
# 886         0       2  27.0      0      0  13.0000        True   True
# 887         1       1  19.0      0      0  30.0000       False   True
# 888         0       3   NaN      1      2  23.4500       False  False
# 889         1       1  26.0      0      0  30.0000        True   True
# 890         0       3  32.0      0      0   7.7500        True   True
#
# [891 rows x 8 columns]

# %%
titanic[['survived', 'pclass','age','sibsp','parch','fare','adult_male','alone']]
# Out:
#      survived  pclass   age  sibsp  parch     fare  adult_male  alone
# 0           0       3  22.0      1      0   7.2500        True  False
# 1           1       1  38.0      1      0  71.2833       False  False
# 2           1       3  26.0      0      0   7.9250       False   True
# 3           1       1  35.0      1      0  53.1000       False  False
# 4           0       3  35.0      0      0   8.0500        True   True
# ..        ...     ...   ...    ...    ...      ...         ...    ...
# 886         0       2  27.0      0      0  13.0000        True   True
# 887         1       1  19.0      0      0  30.0000       False   True
# 888         0       3   NaN      1      2  23.4500       False  False
# 889         1       1  26.0      0      0  30.0000        True   True
# 890         0       3  32.0      0      0   7.7500        True   True
#
# [891 rows x 8 columns]

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue= 'pclass')

# %%
titanic.iloc[:, [0,1,3,4,5,6,10,14]].corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8,6))
sns.heatmap(titanic.iloc[:, [0,1,3,4,5,6,10,14]].corr(), annot = True, annot_kws={"size": 8} , fmt=".2f", linewidth=.5 , cmap='YlGnBu', square=True)
# Out:
# <Axes: >

# %%
sns.clustermap(iris.drop('species' , axis=1))
